# %% [markdown]
# Defense in Depth
# - Don't think one solution is THE Solution. More measures in place adds more layers in security.
#
# Always Be Vigilant
#
# Write Scripts
#
# Keep It Simple
#
# Don't Put All of Your Data in One Database
# - Virtualization
# - If one gets compromise, does everything else get compromise?
#
# OS: Cubes
# - Self-contain every single process
#
# Basic Password Security
# - Brute Force
# - Password Length
#     - 4 chars: 456,976 combinations
#     - 12 chars: 95Q
#
# - Password Complexity
# - Password Rotation
# - Recommend Passphrases & 12 character minimum
# - Password Manager
#     - Install LastPass
# - Multi-Factor Auth
#     - Something you know
#     - Something you have
#     - Something you are
#
# - Disable Guest Accounts
# - Secure Patches and Automatic Updates
#     - Windows Updates
#     - Ubuntu unattended-upgrades
#     - Security Patch Notifications
#         - Sign up for notifications for our servers
#         - WE NEED TO PROTECT SERVERS AT ALL TIMES!!!!!
#     - Shared accounts and account maintenance
#         - Do not let people share accounts and passwords!
#         - Lab: Generatre an employee onboarding/exit document
#         - Run a script
# - Encryption
#     - Encrypt everything
#     - Disk Encryption
#     - BIOS Passwords
#
# - Admin Workstation Hardening
#     - Lock Screen
#         - Always lock when you leave
#         - Locking Shortcuts
#         - Enable on suspend/hibernation/awake
# - Basic Browser Security
#     - HTTPS Everywhere
#     - Adblock Plus
#     - Privacy Badger
#     - NoScript(optional)
# - Windows Anti-Virus
#
# Sudo: Super User Do
# ```
# sudo adduser username
#
# sudo group username
#
# sudo su username
#
# sudo visudo
# ```
#
#
# NOT SUGGESTED
# ```
# sudo usermod -aG sudo username
# ```
#
# visudo
#
# username ALL=(user permission) /location
#
# ```
# ll /usr/lib
# ```
#
# man hier: filesystem hierarchy (USEFUL)
#
# trail
# ```
# sudo tail /var/log/auth.log
# ```
#
# sudo visudo
#
# Defaults insults
#
# SSH
# - public/private key
# ```
# cat ~/.ssh/id_rsa.pub
# cat ~/.ssh/id_rsa
# ```
